# %%
import numpy as np
a=np.array([[0,2],[2,3]])
print("...Matrix A...\n",a)
value,vector=np.linalg.eig(a)
print("\nEigen values : \n",value)
print("\nEigen vector : \n",vector)
# Out:
# ...Matrix A...
#  [[0 2]
#  [2 3]]
#
# Eigen values :
#  [-1.  4.]
#
# Eigen vector :
#  [[-0.89442719 -0.4472136 ]
#  [ 0.4472136  -0.89442719]]
