# %%
import pandas as pd
lst=[11,33,55,77,99]
print("Original list : ",lst)
print("After conversion : ",pd.Series(lst))
# Out:
# Original list :  [11, 33, 55, 77, 99]
# After conversion :  0    11
# 1    33
# 2    55
# 3    77
# 4    99
# dtype: int64
