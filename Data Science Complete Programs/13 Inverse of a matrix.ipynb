# %%
import numpy as np
a=np.array([[4,3],[3,2]])
print("...Matrix A...\n",a)
print("Inverse of matrix A \n",np.linalg.inv(a))
# Out:
# ...Matrix A...
#  [[4 3]
#  [3 2]]
# Inverse of matrix A
#  [[-2.  3.]
#  [ 3. -4.]]
