# %%
import matplotlib.pyplot as plt
with open("plot.txt") as f:
  data=f.read()
data=data.split('\n')
x=[row.split(' ')[0] for row in data]
y=[row.split(' ')[1] for row in data]
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-24748c661de6> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("plot.txt") as f:
#       3   data=f.read()
#       4 data=data.split('\n')
#       5 x=[row.split(' ')[0] for row in data]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plot.txt'
