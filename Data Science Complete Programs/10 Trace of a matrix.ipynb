# %%
import numpy as np
a=np.arange(9).reshape(3,3)
print("...Matrix A...\n",a)
print("Trace of matrix A = ",np.trace(a))
# Out:
# ...Matrix A...
#  [[0 1 2]
#  [3 4 5]
#  [6 7 8]]
# Trace of matrix A =  12
