# %%
import numpy as np
a=np.array([[50,29],[30,44]])
print("...Matrix A...\n",a)
print("Determinant of matrix A = ",np.linalg.det(a))
# Out:
# ...Matrix A...
#  [[50 29]
#  [30 44]]
# Determinant of matrix A =  1330.0000000000002
