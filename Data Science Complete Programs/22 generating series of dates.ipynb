# %%
import pandas as pd
result=pd.date_range(start='01-08-2023',end='01-12-2023')
print("Series of dates : \n",result)
# Out:
# Series of dates :
#  DatetimeIndex(['2023-01-08', '2023-01-09', '2023-01-10', '2023-01-11',
#                '2023-01-12'],
#               dtype='datetime64[ns]', freq='D')
