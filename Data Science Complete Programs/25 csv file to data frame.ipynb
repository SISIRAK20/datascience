# %%
import pandas as pd
data=pd.read_csv('sample.csv')
print("csv file:\n",data)
df=pd.DataFrame(data)
print("DataFrame:\n",df)
# Out:
# csv file:
#    html html.1 html.2
# 0    c    cpp   java
# 1  100    200    300
# DataFrame:
#    html html.1 html.2
# 0    c    cpp   java
# 1  100    200    300
